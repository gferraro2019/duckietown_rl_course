# %%
import pyarrow.parquet as pq

# Load the Parquet file
table = pq.read_table("duckiebot_interactions_19-02-2025_17h21m10s.parquet")

# Convert to Pandas DataFrame (optional)
df = table.to_pandas()

# Display the data
print(df)
# Out:
#      action  reward  terminated  truncated info
# 0       NaN       0       False      False   {}
# 1       NaN       0       False      False   {}
# 2       NaN       0       False      False   {}
# 3       NaN       0       False      False   {}
# 4       NaN       0       False      False   {}
# ..      ...     ...         ...        ...  ...
# 637     NaN       0       False      False   {}
# 638     0.0       0       False      False   {}
# 639     NaN       0       False      False   {}
# 640     NaN       0       False      False   {}
# 641     NaN       0       False      False   {}
#
# [642 rows x 5 columns]
